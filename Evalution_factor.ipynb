# %%
from eval import comparision_histplot, calculate_mean_cov, comparision_histplot_simulation

# %%
import numpy as np

# %%
training_data_path = "/home/yinbinha/adapted_diffusion_model/simulation_experiment_data/training_data_example.npy"

# %%
training_data = np.load(training_data_path)

# %%
np.shape(training_data)
# Out:
# (512, 32, 64)

# %%
generated_data_path = "/home/yinbinha/adapted_diffusion_model/samples/dfm_training_data_example_ts1762564339_seed42/sample_batch2.npy"

# %%
generated_data = np.load(generated_data_path)

# %%
np.shape(generated_data)
# Out:
# (128, 2048)

# %%
mean, cov = calculate_mean_cov(training_data[1])

# %%
comparision_histplot_simulation(1, training_data_path, generated_data_path, mean, cov)
# Out:
# Generated Samples: -1.7116442 1.3004787 0.04 0.328
# Training Samples: -2.2443848 2.5002766 0.011 0.353
# Ground Truth: 0.144 0.256
# /home/yinbinha/adapted_diffusion_model/eval/simulation_eval.py:100: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# array([-1.7116442 , -1.6514018 , -1.5911592 , -1.5309168 , -1.4706744 ,
#        -1.4104319 , -1.3501894 , -1.2899469 , -1.2297045 , -1.1694621 ,
#        -1.1092196 , -1.0489771 , -0.98873466, -0.92849225, -0.8682498 ,
#        -0.8080073 , -0.7477648 , -0.6875224 , -0.62727994, -0.56703746,
#        -0.50679505, -0.44655257, -0.3863101 , -0.32606766, -0.26582518,
#        -0.20558274, -0.14534028, -0.08509782, -0.02485537,  0.03538709,
#         0.09562955,  0.155872  ,  0.21611446,  0.27635694,  0.33659938,
#         0.39684182,  0.4570843 ,  0.5173268 ,  0.5775692 ,  0.63781166,
# ...

# %%
emirical_data_path = "empirical_analysis_data/training_data_example.npy"

# %%
emirical_data = np.load(emirical_data_path)

# %%
np.shape(emirical_data)
# Out:
# (1194, 512)
